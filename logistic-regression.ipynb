# %% [raw]
# First lets create some data that obeys the implicit assumption of logistic regression

# %%
# p(x) ~ uniform(0,1)
# r = a + bx1+ cx2 + e, where e ~ N(0,sigma)
# p(y|r) = logistic(r)
    
rows = 500
xe = ones((rows,3))
x = uniform(size = (rows,2),low=-2.0,high=2.0)
xe[:,1:] = x
w = [3,-2,-1]
r = xe.dot(w) + normal(size=rows,loc=0,scale=1)
#r = r - mean(r)
g = (exp(r))/(1+exp(r))
y = (uniform(size=rows) <= g)
scatter(x[:,0],x[:,1],c = y)
xlabel("x1")
ylabel("x2")
show()

data = zeros((rows,3))
data[:,0] = y
data[:,1:] = x
print data
# Out:
# [[ 1.         -0.327189    1.2146649 ]
#  [ 1.          0.15550199  1.03911923]
#  [ 1.          1.00867572 -1.11973262]
#  ...,
#  [ 1.         -1.88538276  0.57929638]
#  [ 0.          0.27466271  1.15704675]
#  [ 1.         -0.4373331  -0.51945639]]

# %%
# Now lets model with logistic regression and try to recover
from sklearn import linear_model

logreg = linear_model.LogisticRegression(C=1)
logreg.fit(x, y)

x_min, x_max = x[:, 0].min() - .5, x[:, 0].max() + .5
y_min, y_max = x[:, 1].min() - .5, x[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
figure(1, figsize=(4, 3))
pcolormesh(xx, yy, Z, cmap=cm.Paired)

# Plot also the training points
scatter(x[:, 0], x[:, 1], c=y, edgecolors='k', cmap=cm.Paired)


xlim(xx.min(), xx.max())
ylim(yy.min(), yy.max())
xticks(())
yticks(())

show()
