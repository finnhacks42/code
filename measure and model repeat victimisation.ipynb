# %% [markdown]
# # Measuring and Modeling Repeat Victimisation Paper

# %%
counts = [80000,7002,819,98,19,5,1]
nburgs = range(len(counts))
plot(nburgs,counts,'or')
show()

# %%
# Claim: A simple Poisson model does not fit this data -> repeat victimisation is occuring.

# a simple poisson model
# - assume all houses equally likely to be targeted.
