# %%
x = random.random(10000)
hist(x,normed=1)
show()
y = sqrt(x)
hist(y,normed=1)
show()

# %%
# generate some data X->Y given some invertible, determinisitic function f
# Estimate f, E(y|x) as a polynomial
# Calculate f'
# Plot correlation between p(x) and f'(x)
# Plot correlation between p(yP and f'(x)
x = random.random(100)
y = sqrt(x)
plot(x,y,".")
show()

# Estimate f
