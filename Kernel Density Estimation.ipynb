# %%
# read in the data file
import pandas as pd
data = pd.read_csv("/home/finn/programming/ebay/lego.csv",header=None)
perKilo = data[4]
hist(perKilo)
show()
print median(perKilo)
print len(data)
# Out:
# 33.6018518519
# 358

# %%
# separate lego from duplo
data[0] = data[0].str.lower()
duplo = data[data[0].str.contains('duplo')]
lego = data.drop(duplo.index)
print len(duplo),len(lego),len(duplo)+len(lego)
# Out:
# 45 313 358

# %%
duploPerKilo = list(duplo[4])
#hist(duploPerKilo)
#show()
#legoPerKilo = list(lego[4])
#hist(legoPerKilo)
#show()
print "Lego Per Kilo",median(legoPerKilo)
print "Duplo Per Kilo",median(duploPerKilo)


matplotlib.rcParams.update({'font.size': 12})
figure(figsize=(8,6),dpi=300)
xlim(0,100)
xticks(range(0,100,5))
xlabel("$Au per kg")
yticks([])
title("The cost of second hand Lego and Duplo per kg")
gca().axes.get_yaxis().set_visible(False)

#titanic.fare.dropna().plot(kind='kde', xlim=(0,600))
duplo[4].dropna().plot(kind='kde',bw_method=0.2,linewidth=2.5,label="Duplo")
lego[4].dropna().plot(kind='kde',bw_method=0.2,linewidth=2.5,label="Lego")
ylabel("Estimated Probability Density")
legend(loc='upper right')
show()
# Out:
# Lego Per Kilo 34.9285714286
# Duplo Per Kilo 26.3333333333

# %%
# Create a figure of size 8x6 inches, 80 dots per inch
pl.figure(figsize=(8, 6), dpi=80)

# Create a new subplot from a grid of 1x1
pl.subplot(1, 1, 1)
see if I can do a nice smooth kernel density estimation
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# Plot cosine with a blue continuous line of width 1 (pixels)
pl.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# Plot sine with a green continuous line of width 1 (pixels)
pl.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x limits
pl.xlim(-4.0, 4.0)

# Set x ticks
pl.xticks(np.linspace(-4, 4, 9, endpoint=True))

# Set y limits
pl.ylim(-1.0, 1.0)

# Set y ticks
pl.yticks(np.linspace(-1, 1, 5, endpoint=True))
# Out:
# 1       31.111111
# 8       25.043902
# 16      21.428571
# 17      25.660000
# 18      47.037037
# 19      25.000000
# 24      20.666667
# 29      13.666667
# 40      29.366197
# 49      31.538462
# 53      34.900000
# 54      23.480000
# 56      39.673913
# 57      38.888889
# 68      36.500000
# 81      25.200000
# 90      34.900000
# 91      35.300000
# 105     61.333333
# 111     16.812500
# 141     20.833333
# 145     31.700000
# 150     26.581667
# 160     25.516667
# 162     26.000000
# 177     25.714286
# 213     13.791667
# 219     29.285714
# 222     35.000000
# 223    137.500000
# 228     12.500000
# 230     28.615385
# 232     26.673333
# 233     25.714286
# 239     20.010000
# 258     26.333333
# 264     20.500000
# 268     38.452381
# 269     10.250000
# 270     34.615385
# 273     22.666667
# 282     28.000000
# 306     23.571429
# 319     30.769231
# 323     16.000000
# Name: 4, dtype: float64
