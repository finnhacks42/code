# %%
import networkx as nx

# generate some graph
n = 5
G = nx.scale_free_graph(n)	
nx.draw_spring(G)
show()

# %%
a = 0.1
x = random.pareto(a, 10)
hist(x)
show()

# %%
# simulate some cascades on the graph
a = 1
b = 0.5

num_cascades = 5
cascades = []
for c in range(num_cascades):
    hits = []
    start = randint(n)
    # decend through children
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-df14d7cd3012> in <module>()
#       7 for c in range(num_cascades):
#       8     hits = []
# ----> 9     start = randint(n)
#      10
#      11
#
# NameError: name 'n' is not defined

# %%
# try to infer the graph structure from the cascades
